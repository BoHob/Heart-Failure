# %% [markdown]
# <a href="https://colab.research.google.com/github/BoHob/Heart-Failure/blob/main/Project_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.read_csv ('https://raw.githubusercontent.com/BoHob/google-stock/main/Greenhouse%20Gas%20Emissions%20worldwide.csv')

#mean for all values
df.mean(axis = 0, skipna = True)
df.head()
df=df.transpose()
df.head()
df.columns=df.iloc[0]
df.reset_index(inplace=True)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   import sys
# Country or Area              index    Australia    Australia    Australia  \
# 0                  Country or Area    Australia    Australia    Australia
# 1                             Year         2012         2011         2010
# 2                    co2_gigagrams  397830.6047  398161.3872  399364.8191
# 3                    hfc_gigagrams  7945.106379  7512.150105  6942.606891
# 4                methane_gigagrams  111709.4988  110274.7423  109062.6389
#
# Country or Area    Australia    Australia    Australia    Australia  \
# 0                  Australia    Australia    Australia    Australia
# 1                       2009         2008         2007         2006
# ...

# %%
# Minimum values
df.min(axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# dtype: float64

# %%
# Maximum values
df.max(axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# dtype: float64
